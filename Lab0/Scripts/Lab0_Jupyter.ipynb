# %% [markdown]
# ## GIS 5571 Lab 0

# %%
import geopandas as gpd

gdf = gpd.read_file('Bikeways.shp') # Read shapefile

# %%
gdf[1:10] # Look at first 9 rows of data
# Out:
#    OBJECTID               SOURCE  SIDE         TYPE JURISDICTI  ACTIVE  \
# 1     16286  City of Minneapolis  None  Paved Trail       None       1
# 2     16287  City of Minneapolis  None  Paved Trail       None       1
# 3     16290  City of Minneapolis  None  Paved Trail       None       1
# 4     16291  City of Minneapolis  None  Paved Trail       None       1
# 5     16295  City of Minneapolis  None  Paved Trail       None       1
# 6     16298  City of Minneapolis  None  Paved Trail       None       1
# 7     16300    Mpls Public Works    NA  Paved Trail  Municipal       0
# 8     16302    Mpls Public Works  Both    Bike Lane  Municipal       0
# 9     96873        Ramsey County  None    Bike Lane       None       0
#
#             NOTES            NAME FAC_ID  MILES  ...  SUITABILIT SHLD_DATE  \
# 1        11/20/06            None   None    0.0  ...        None      None
# 2        11/20/06            None   None    0.0  ...        None      None
# ...

# %%
import matplotlib.pyplot as plt
gdf.plot()
plt.show()

# %%
buf_gdf = gdf.buffer(5) # Buffer

buf_gdf.plot()
plt.show()

# %%
buf_gdf[1:10]
# Out:
# 1    POLYGON ((474880.645 4980900.871, 474867.205 4...
# 2    POLYGON ((474885.172 4980973.638, 474885.509 4...
# 3    POLYGON ((474876.994 4981096.024, 474876.513 4...
# 4    POLYGON ((474330.191 4980467.950, 474330.561 4...
# 5    POLYGON ((474428.057 4980482.053, 474438.472 4...
# 6    POLYGON ((474038.427 4977995.538, 474031.201 4...
# 7    POLYGON ((477643.869 4970585.118, 477643.845 4...
# 8    POLYGON ((479896.413 4971259.902, 479896.550 4...
# 9    POLYGON ((500438.158 4973216.987, 500438.139 4...
# dtype: geometry
